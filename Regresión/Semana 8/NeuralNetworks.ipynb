# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg" width="350px" height="180px" />
#
#
# # <font color= #8A0829> Laboratorio de Modelado de Datos </font>
# #### <font color= #2E9AFE> `Martes y Viernes (Videoconferencia) de 13:00 - 15:00 hrs`</font>
# - <Strong> Sara Eugenia Rodríguez </Strong>
# - <Strong> Año </Strong>: 2025
# - <Strong> Email: </Strong>  <font color="blue"> `cd682324@iteso.mx` </font>
# ___
#
# <p style="text-align:right;"> Imagen recuperada de: https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg</p>
#
# ### <font color= #2E9AFE> Tema: Redes Neuronales</font>

# %% [markdown]
# Las redes neuronales profundas (deep learning) han ganado mucha popularidad en los últimos años, especialmente para problemas complejos, como el reconocimiento de imágenes, el procesamiento del lenguaje natural y otras aplicaciones que requieren modelos potentes.
#
# Sin embargo, las redes neuronales básicas también pueden usarse en problemas de aprendizaje supervisado más simples, como regresión o clasificación, AUNQUE hay varias razones por las cuales otros algoritmos son más comunes en estos casos...
#
# 1. Complejidad computacional
# 2. Sobreajuste (Overfitting)
# 3. Necesidad de más datos
# 4. Tuning de Hiperparámetros (las redes neuronales tienen muchos hiperparámetros)
# 5. Interpretabilidad, son modelos de caja negra
#
# **¿Cuándo se utilizan redes neuronales en aprendizaje supervisado?**
#
# Aunque no siempre son la primera opción para problemas simples, las redes neuronales pueden ser muy útiles en problemas supervisados más complejos donde:
#
# - Hay gran cantidad de datos disponibles
# - Los problemas son no lineales
# - Hay tareas de percepción involucradas (como visión por computadora, reconocimiento de voz o procesamiento de lenguaje natural), donde las redes neuronales profundas sobresalen.

# %% [markdown]
# Dentro de la caja negra...
#
# **¿Qué es una neurona?**
#
# Es un nombre elegante que le pusieron para referirse a una función en los años de 1940-1950. Se creeía que los nodos eran como neuronas del cerebro.
#
# **¿Qué es una función?**
#
# Es un nombre elegante que pusieron para referirse a algo que toma cosas de entrada, aplica alguna lógica y saca un resultado.
#
# **¿Qué es una red neuronal?**
#
# Es la interconexión de múltiples neuronas (funciones) para resolver un problema complejo que una sola neurona no podría. Dentro de los componentes existen *nodos* y *conexiones*
#
# **Pasos que hace la red neuronal:**
#
# 1. Combinación de las variables de entrada (X). Cada señal recibida tiene una constante w (peso/weight) que permite manipular la importancia de cada variable de entrada.
# 2. Neurona de respuesta. Considerando todas las variables de entrada, la neurona genera una señal de respuesta a través de una función.
#
# **Tipos de capas en la red neuronal**
#
# - Capa de entrada: capa que toma los datos de entrada
# - Capas ocultas: toman las entradas de otra capa y pasan a salida hacia otra capa (son intermediarias entre la entrada y la salida)
# - Capas de salida: capa que hace la predicción
#
# <img style="float: center; margin: 0px 0px 0px 0px;" src="https://www.smartsheet.com/sites/default/files/IC-simplified-artificial-neural-networks-corrected.svg" width="350px" height="180px" />

# %% [markdown]
# **Funciones de activación**
#
# El comportamiento de las neuronas de las redes neuronales es basado en la función en la que la neurona se especializó. Una neurona puede cambiar su respuesta dependiendo de la función de activación $\varphi(*)$ que sea seleccionada
#
# Funciones comunes:
# 1. Lineal: $\varphi(\nu)=\nu$
# 2. Sigmoidal: $\varphi(\nu)=\frac{e^{\nu}}{1+e^{\nu}}$
# 3. Tanh: $\varphi(\nu)=\frac{e^{\nu}-e^{-\nu}}{e^{\nu}+e^{-\nu}}=tanh(\nu)$
# 4. Softplus: $\varphi(\nu)=log(1+e^{\nu})$
# 5. RELU: $\varphi(\nu)=max(0,\nu)$
#
# Las funciones de activación suelen ser diferenciables, lo que significa que la derivada de primer orden se puede calcular para un valor de entrada dado. Esto es necesario dado que las redes neuronales generalmente se entrenan utilizando el algoritmo de backpropagation que requiere la derivada del error de predicción para actualizar los pesos del modelo.
#
# **¿Cómo elegir la función de activación para las capas ocultas?**
#
# - RELU: es la más utilizada para capas ocultas. Es fácil de calcular, lo que la hace más rápida para entrenar. Es simple de implementar y no es tan susceptible a gradientes que se desvanecen
# - Leaky RELU: Similar a ReLU, pero permite valores negativos pequeños cuando x≤0, lo que evita que las neuronas queden completamente inactivas.
# - Evita Sigmoid y Tanh en las capas ocultas
#
# **¿Cómo elegir la función de activación para las capas de salida?**
#
# - Lineal: Para problemas de regresión donde la salida es un valor continuo.
# - Sigmoidal: típicamente para problemas de clasificación binaria.
# - Softmax: Para problemas de clasificación multiclase
#
#
# **¿Cómo son las redes neuronales para regresión?**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# <font color= #2E9AFE>$$y^{2} = \varphi(\nu^{2})$$</font>
#
# La única diferencia es la última salida. La función de la salida tiene que ser **lineal**
#
#
# **¿Cómo elegir cuántas capas ocultas?**
#
# - Problemas sencillos: Una sola capa oculta suele ser suficiente para capturar patrones simples.
# - Problemas más complejos (con relaciones no lineales más complicadas): Dos capas ocultas pueden ser útiles
#
# En la práctica, la mayoría de los problemas sencillos no necesitan más de 1 o 2 capas ocultas.
#
# **¿Cómo elegir cuántas neuronas en las capas ocultas?**
#
# - Un buen punto de partida es comenzar con un número de neuronas que sea similar o cercano al número de características de entrada.
# - Para problemas simples, puedes comenzar con entre 4 y 16 neuronas por capa.
# - Si los datos tienen una cantidad moderada de complejidad o son no lineales, podrías aumentar a 32 o 64 neuronas en la capa oculta.
# - Evita tener muchas más neuronas que características de entrada, ya que eso puede llevar a un sobreajuste.
# - En redes con múltiples capas ocultas, una estrategia común es que las capas posteriores tengan menos neuronas que las capas iniciales. Esto es porque las primeras capas extraen más características, mientras que las capas más profundas se enfocan en combinarlas.
#
# **Recomendaciones**
#
# - Se recomienda hacer un pre-procesamiento de los datos - Escalamiento
# - Comúnmente todas las capas ocultas usan la misma función de activación
# - La función de salida generalmente usa diferente función de activación que el de las capas ocultas.
# - En la experiencia, conviene más aumentar el número de neuronas ocultas en lugar de aumentar el número de capas ocultas.
# - Se recomienda no usar muchas capas ocultas
#
#
# **¿Por qué el deep learning no funciona tan bien en problemas clásicos de regresión/clasificación?**
#
# Gran parte del éxito de las redes neuronales modernas proviene de su capacidad para explotar la naturaleza compositiva del mundo. Es decir, en problemas de percepción como el análisis de imágenes o audio, las características tienen un orden (espacial o temporal) y los patrones locales se agregan para formar conceptos y objetos de nivel superior (por ejemplo, la imagen de un automóvil está hecha de ruedas y otras partes, que están hechas de características visuales de nivel inferior, que están hechas de formas básicas como bordes, círculos y líneas, etc.).
#
# Las redes neuronales modernas, como las redes neuronales convolucionales (CNN), aprovechan esto aprendiendo características cada vez más abstractas en las capas más profundas.
#
# Por el contrario, los problemas de regresión clásicos constan de una serie de características no ordenadas, y el valor objetivo se puede predecir bastante bien con un modelo lineal/no lineal superficial de las características de entrada. En cierto sentido, esta propiedad composicional presente en problemas como la clasificación de imágenes o el reconocimiento de voz no está presente en problemas como "Predecir los ingresos de un individuo en función de su sexo, edad, nacionalidad, grado académico, tamaño de la familia...".

# %% [markdown]
# ## Ejemplo: Eficiencia de Energia
#
# Se busca analizar la eficiencia energética de los edificios.
#
# Se realizaron análisis energéticos utilizando 12 tipos de edificios diferentes simulados en Ecotect.
#
# Los edificios se diferencian en cuanto a la superficie con cristales, la distribución del área acristalada y la orientación, entre otros parámetros.
#
# Se simularon varios escenarios en función de las características antes mencionadas para obtener 768 formas de edificios.
#
# El conjunto de datos comprende 768 muestras y 8 características, con el objetivo de predecir dos respuestas con valor real.
#
# Información de atributos:
# - X1 Relative Compactness
# - X2 Surface Area
# - X3 Wall Area
# - X4 Roof Area
# - X5 Overall Height
# - X6 Orientation
# - X7 Glazing Area
# - X8 Glazing Area Distribution
#
# Targets:
# - Y1: Heating Load (in Wh)
# - Y2: Cooling Load (in Wh)
# -
# Las características son numéricas y representan diversas características físicas del edificio, mientras que las variables objetivo representan la energía necesaria para calefacción y enfriamiento.

# %%
##pip install tensorflow

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ENB2012_data.csv")

df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
df.describe()
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1          Y2
# count  768.000000  768.00000  768.000000  768.000000
# mean     0.234375    2.81250   22.307201   24.587760
# std      0.133221    1.55096   10.090196    9.513306
# min      0.000000    0.00000    6.010000   10.900000
# 25%      0.100000    1.75000   12.992500   15.620000
# 50%      0.250000    3.00000   18.950000   22.080000
# 75%      0.400000    4.00000   31.667500   33.132500
# max      0.400000    5.00000   43.100000   48.030000

# %%
#Matriz de correlaciones
correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
#Correlaciones con el target
correlation_target = df.corr()[['Y1','Y2']]
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_target, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Target')
plt.show()

# %%
#Distribucion de las varialbes
sns.pairplot(df)

# %% [markdown]
# ### Modelado

# %% [markdown]
# Vamos a usar una red compartida con dos salidas (cooling and heating load), ya que los dos targets están físicamente relacionados y la red puede aprender representaciones compartidas.
#
# Algunos tips para empezar la arquitectura inicial de la red:
#
# **a. Entrada y salida**
#
# - Entradas: 8 características → tamaño de capa de entrada = 8
# - Salidas: 2 objetivos → tamaño de capa de salida = 2
#
# **b. Capas ocultas**
#
# Por lo general, comienzas poco a poco y vas ampliando:
#
# - Comienza con 1 a 2 capas ocultas.
# - Numero de neuronas: entre el tamaño de entrada y salida (8) y tal vez entre 2 y 4 veces más (16–32–64).
#
# Por ejemplo:
# Input (8)
# ↓
# Dense(64, ReLU)
# ↓
# Dense(32, ReLU)
# ↓
# Dense(2, Linear)
#
# **c. Funcion de activacion**
#
# Comenzar con RELU para capas ocultas
#
# **d. Agregar Regularizacion**
#
# Agregar regularizacion si vemos overfitting (dropout)
#
# **e. Funcion de costo**
#
# MSE
#
# **f. Optimizer**
#
# Adam

# %%
X = df[['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8']].values
y1 = df['Y1'].values  # Heating Load
y2 = df['Y2'].values  # Cooling Load

# %%
X_train, X_test, y1_train, y1_test, y2_train, y2_test = train_test_split(X, y1, y2, test_size=0.2, random_state=42)

# %%
# Estandarizamos los datos
scaler=StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Modelo Baseline

# %%
# Capa de entrada (8 variables)
input_layer = Input(shape=(X_train.shape[1],), name='input_layer')

# Capas ocultas compartidas
layer_dense1_shared=Dense(64 , activation='relu', name='shared_dense_1')(input_layer)
layer_dense2_shared=Dense(32,activation='relu',name='shared_dense_2')(layer_dense1_shared)
layer_dropout1_shared=Dropout(0.2,name='shared_dropout_1')(layer_dense2_shared)

#Estructura para Y1 (Heating Load)
y1_dense_1=Dense(32, activation='relu',name='y1_dense_1')(layer_dropout1_shared)
y1_dropout = Dropout(0.2, name='y1_dropout')(y1_dense_1)
y1_dense2 = Dense(16, activation='relu', name='y1_dense_2')(y1_dropout)
y1_output = Dense(1, name='y1_output')(y1_dense2)

#Estructura para Y2 (Cooling Load)
y2_dense1 = Dense(32, activation='relu', name='y2_dense_1')(layer_dropout1_shared)
y2_dropout = Dropout(0.2, name='y2_dropout')(y2_dense1)
y2_dense3 = Dense(16, activation='relu', name='y2_dense_3')(y2_dropout)
y2_output = Dense(1, name='y2_output')(y2_dense3)

# %%
#  Modelo que contenga la capa de entrada y las capas de salida 
model=Model(inputs=input_layer  ,outputs=[y1_output , y2_output])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_1      │ (None, 64)        │        576 │ input_layer[0][0] │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_2      │ (None, 32)        │      2,080 │ shared_dense_1[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dropout_1    │ (None, 32)        │          0 │ shared_dense_2[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dropout          │ (None, 32)        │          0 │ y1_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dropout          │ (None, 32)        │          0 │ y2_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_2 (Dense)  │ (None, 16)        │        528 │ y1_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_3 (Dense)  │ (None, 16)        │        528 │ y2_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_output (Dense)   │ (None, 1)         │         17 │ y1_dense_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_output (Dense)   │ (None, 1)         │         17 │ y2_dense_3[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,858 (22.88 KB)
#  Trainable params: 5,858 (22.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilamos el modelo

model.compile(optimizer='adam', 
              loss={'y1_output': 'mse', 'y2_output': 'mse'}, 
              metrics={'y1_output': 'mae', 'y2_output': 'mae'})

# Entrenamos el modelo
history = model.fit(X_train, [y1_train, y2_train], epochs=200, batch_size=32, 
                    validation_data=(X_test, [y1_test, y2_test]))
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1236.8953 - y1_output_loss: 571.5721 - y1_output_mae: 21.9516 - y2_output_loss: 641.6198 - y2_output_mae: 23.7392 - val_loss: 1245.9403 - val_y1_output_loss: 593.1139 - val_y1_output_mae: 22.0488 - val_y2_output_loss: 663.0486 - val_y2_output_mae: 23.7825
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1056.8809 - y1_output_loss: 511.9435 - y1_output_mae: 20.4264 - y2_output_loss: 538.3030 - y2_output_mae: 21.2000 - val_loss: 912.9537 - val_y1_output_loss: 473.6457 - val_y1_output_mae: 19.3197 - val_y2_output_loss: 448.2551 - val_y2_output_mae: 18.9029
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 592.4279 - y1_output_loss: 340.0842 - y1_output_mae: 15.7348 - y2_output_loss: 242.8438 - y2_output_mae: 12.6820 - val_loss: 260.8474 - val_y1_output_loss: 192.0626 - val_y1_output_mae: 11.0035 - val_y2_output_loss: 72.6461 - val_y2_output_mae: 6.1447
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 182.1863 - y1_output_loss: 101.5301 - y1_output_mae: 7.4460 - y2_output_loss: 83.0917 - y2_output_mae: 6.8397 - val_loss: 81.0745 - val_y1_output_loss: 39.0425 - val_y1_output_mae: 4.3730 - val_y2_output_loss: 43.2762 - val_y2_output_mae: 4.7571
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 109.9518 - y1_output_loss: 53.0339 - y1_output_mae: 5.3901 - y2_output_loss: 57.1421 - y2_output_mae: 5.7832 - val_loss: 70.3069 - val_y1_output_loss: 30.1108 - val_y1_output_mae: 3.8378 - val_y2_output_loss: 40.8233 - val_y2_output_mae: 4.8173
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 93.7403 - y1_output_loss: 44.6460 - y1_output_mae: 4.8762 - y2_output_loss: 48.2989 - y2_output_mae: 5.3251 - val_loss: 61.2481 - val_y1_output_loss: 27.3722 - val_y1_output_mae: 3.6553 - val_y2_output_loss: 34.2303 - val_y2_output_mae: 4.4401
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 82.3701 - y1_output_loss: 42.9669 - y1_output_mae: 4.7224 - y2_output_loss: 39.7148 - y2_output_mae: 4.8560 - val_loss: 56.1054 - val_y1_output_loss: 25.2886 - val_y1_output_mae: 3.4418 - val_y2_output_loss: 31.1167 - val_y2_output_mae: 4.1554
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 82.0232 - y1_output_loss: 41.9446 - y1_output_mae: 4.6064 - y2_output_loss: 45.1497 - y2_output_mae: 5.0623 - val_loss: 54.2113 - val_y1_output_loss: 23.2252 - val_y1_output_mae: 3.2848 - val_y2_output_loss: 31.2900 - val_y2_output_mae: 4.0284
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 79.2367 - y1_output_loss: 37.5491 - y1_output_mae: 4.5968 - y2_output_loss: 39.6849 - y2_output_mae: 4.7631 - val_loss: 47.7475 - val_y1_output_loss: 21.6627 - val_y1_output_mae: 3.1519 - val_y2_output_loss: 26.2916 - val_y2_output_mae: 3.7402
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 75.1623 - y1_output_loss: 35.8799 - y1_output_mae: 4.3840 - y2_output_loss: 40.3177 - y2_output_mae: 4.7412 - val_loss: 48.4079 - val_y1_output_loss: 22.0485 - val_y1_output_mae: 3.1269 - val_y2_output_loss: 26.6085 - val_y2_output_mae: 3.6880
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 75.5286 - y1_output_loss: 35.1598 - y1_output_mae: 4.4741 - y2_output_loss: 44.5299 - y2_output_mae: 4.7453 - val_loss: 46.0288 - val_y1_output_loss: 20.6029 - val_y1_output_mae: 3.0026 - val_y2_output_loss: 25.6312 - val_y2_output_mae: 3.5296
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 67.5053 - y1_output_loss: 33.7687 - y1_output_mae: 4.4326 - y2_output_loss: 33.6729 - y2_output_mae: 4.4485 - val_loss: 41.2090 - val_y1_output_loss: 18.3087 - val_y1_output_mae: 3.0080 - val_y2_output_loss: 23.0575 - val_y2_output_mae: 3.4747
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 73.8967 - y1_output_loss: 35.6234 - y1_output_mae: 4.4056 - y2_output_loss: 39.5254 - y2_output_mae: 4.6701 - val_loss: 40.7074 - val_y1_output_loss: 18.0277 - val_y1_output_mae: 2.8721 - val_y2_output_loss: 22.9078 - val_y2_output_mae: 3.3652
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 68.6716 - y1_output_loss: 34.1036 - y1_output_mae: 4.2709 - y2_output_loss: 33.0773 - y2_output_mae: 4.3422 - val_loss: 38.3473 - val_y1_output_loss: 17.3732 - val_y1_output_mae: 2.7764 - val_y2_output_loss: 21.1954 - val_y2_output_mae: 3.2022
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 65.6055 - y1_output_loss: 31.9027 - y1_output_mae: 4.1436 - y2_output_loss: 33.2377 - y2_output_mae: 4.2289 - val_loss: 35.0501 - val_y1_output_loss: 15.6581 - val_y1_output_mae: 2.8207 - val_y2_output_loss: 19.5198 - val_y2_output_mae: 3.1533
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 61.3280 - y1_output_loss: 29.3526 - y1_output_mae: 4.0931 - y2_output_loss: 30.6058 - y2_output_mae: 4.1623 - val_loss: 35.7225 - val_y1_output_loss: 15.6985 - val_y1_output_mae: 2.6884 - val_y2_output_loss: 20.1952 - val_y2_output_mae: 3.1088
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.3358 - y1_output_loss: 28.1615 - y1_output_mae: 3.9215 - y2_output_loss: 34.2365 - y2_output_mae: 4.3088 - val_loss: 32.8934 - val_y1_output_loss: 14.7735 - val_y1_output_mae: 2.6796 - val_y2_output_loss: 18.2402 - val_y2_output_mae: 3.0543
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.3197 - y1_output_loss: 27.3015 - y1_output_mae: 3.7550 - y2_output_loss: 29.6407 - y2_output_mae: 4.0775 - val_loss: 34.5253 - val_y1_output_loss: 14.3969 - val_y1_output_mae: 2.6250 - val_y2_output_loss: 20.2765 - val_y2_output_mae: 3.0874
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 55.3199 - y1_output_loss: 25.7940 - y1_output_mae: 3.6734 - y2_output_loss: 34.5073 - y2_output_mae: 4.1422 - val_loss: 29.2027 - val_y1_output_loss: 13.2548 - val_y1_output_mae: 2.5052 - val_y2_output_loss: 16.0200 - val_y2_output_mae: 2.8347
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 55.5365 - y1_output_loss: 25.8684 - y1_output_mae: 3.7564 - y2_output_loss: 28.8268 - y2_output_mae: 4.0854 - val_loss: 31.5424 - val_y1_output_loss: 12.9196 - val_y1_output_mae: 2.5066 - val_y2_output_loss: 18.8965 - val_y2_output_mae: 2.9650
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.8711 - y1_output_loss: 27.0287 - y1_output_mae: 3.7437 - y2_output_loss: 28.7217 - y2_output_mae: 4.0345 - val_loss: 30.6739 - val_y1_output_loss: 13.7380 - val_y1_output_mae: 2.5091 - val_y2_output_loss: 17.2019 - val_y2_output_mae: 2.7914
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.2730 - y1_output_loss: 26.5535 - y1_output_mae: 3.8407 - y2_output_loss: 31.2985 - y2_output_mae: 4.1112 - val_loss: 33.0666 - val_y1_output_loss: 14.2999 - val_y1_output_mae: 2.5601 - val_y2_output_loss: 19.0173 - val_y2_output_mae: 2.9049
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 53.9864 - y1_output_loss: 24.1758 - y1_output_mae: 3.7269 - y2_output_loss: 29.9700 - y2_output_mae: 4.0351 - val_loss: 25.4483 - val_y1_output_loss: 11.1693 - val_y1_output_mae: 2.3143 - val_y2_output_loss: 14.3481 - val_y2_output_mae: 2.5752
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.3372 - y1_output_loss: 23.2427 - y1_output_mae: 3.5198 - y2_output_loss: 25.6981 - y2_output_mae: 3.8505 - val_loss: 31.7466 - val_y1_output_loss: 12.8640 - val_y1_output_mae: 2.4002 - val_y2_output_loss: 19.0995 - val_y2_output_mae: 2.9225
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.9616 - y1_output_loss: 21.3848 - y1_output_mae: 3.4923 - y2_output_loss: 27.9116 - y2_output_mae: 3.9487 - val_loss: 25.1025 - val_y1_output_loss: 10.4547 - val_y1_output_mae: 2.2209 - val_y2_output_loss: 14.7375 - val_y2_output_mae: 2.5439
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 48.4197 - y1_output_loss: 23.0323 - y1_output_mae: 3.5791 - y2_output_loss: 25.1166 - y2_output_mae: 3.7586 - val_loss: 23.7716 - val_y1_output_loss: 10.4183 - val_y1_output_mae: 2.2110 - val_y2_output_loss: 13.4230 - val_y2_output_mae: 2.4501
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.0883 - y1_output_loss: 20.0042 - y1_output_mae: 3.3302 - y2_output_loss: 26.2892 - y2_output_mae: 3.7645 - val_loss: 22.0509 - val_y1_output_loss: 9.7888 - val_y1_output_mae: 2.1698 - val_y2_output_loss: 12.3699 - val_y2_output_mae: 2.3429
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 50.6521 - y1_output_loss: 23.7899 - y1_output_mae: 3.5373 - y2_output_loss: 28.0817 - y2_output_mae: 3.8875 - val_loss: 22.0189 - val_y1_output_loss: 9.5167 - val_y1_output_mae: 2.1871 - val_y2_output_loss: 12.6482 - val_y2_output_mae: 2.4157
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 50.4655 - y1_output_loss: 24.3153 - y1_output_mae: 3.6644 - y2_output_loss: 27.2655 - y2_output_mae: 3.8948 - val_loss: 25.0552 - val_y1_output_loss: 11.0060 - val_y1_output_mae: 2.2918 - val_y2_output_loss: 14.2304 - val_y2_output_mae: 2.4627
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 48.6749 - y1_output_loss: 24.0824 - y1_output_mae: 3.5682 - y2_output_loss: 25.2008 - y2_output_mae: 3.7398 - val_loss: 23.0401 - val_y1_output_loss: 9.8897 - val_y1_output_mae: 2.2188 - val_y2_output_loss: 13.3276 - val_y2_output_mae: 2.4625
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.2025 - y1_output_loss: 21.5110 - y1_output_mae: 3.3848 - y2_output_loss: 23.4616 - y2_output_mae: 3.7337 - val_loss: 27.3558 - val_y1_output_loss: 11.6531 - val_y1_output_mae: 2.4267 - val_y2_output_loss: 15.9055 - val_y2_output_mae: 2.7595
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 46.6726 - y1_output_loss: 21.6832 - y1_output_mae: 3.4501 - y2_output_loss: 26.4394 - y2_output_mae: 3.6802 - val_loss: 21.0667 - val_y1_output_loss: 8.7869 - val_y1_output_mae: 2.0630 - val_y2_output_loss: 12.3640 - val_y2_output_mae: 2.3573
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.0760 - y1_output_loss: 20.8456 - y1_output_mae: 3.2205 - y2_output_loss: 25.0899 - y2_output_mae: 3.7295 - val_loss: 23.0436 - val_y1_output_loss: 9.3645 - val_y1_output_mae: 2.1116 - val_y2_output_loss: 13.7795 - val_y2_output_mae: 2.4979
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 43.7700 - y1_output_loss: 20.5747 - y1_output_mae: 3.3590 - y2_output_loss: 22.7507 - y2_output_mae: 3.5826 - val_loss: 21.3272 - val_y1_output_loss: 9.3721 - val_y1_output_mae: 2.1842 - val_y2_output_loss: 12.0847 - val_y2_output_mae: 2.3613
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.9298 - y1_output_loss: 19.3228 - y1_output_mae: 3.2352 - y2_output_loss: 21.0497 - y2_output_mae: 3.4473 - val_loss: 26.7111 - val_y1_output_loss: 11.2790 - val_y1_output_mae: 2.4358 - val_y2_output_loss: 15.6136 - val_y2_output_mae: 2.7488
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 43.3388 - y1_output_loss: 20.0130 - y1_output_mae: 3.2340 - y2_output_loss: 22.8535 - y2_output_mae: 3.6291 - val_loss: 21.0551 - val_y1_output_loss: 8.7891 - val_y1_output_mae: 2.0926 - val_y2_output_loss: 12.3611 - val_y2_output_mae: 2.4026
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.3061 - y1_output_loss: 16.3843 - y1_output_mae: 3.0321 - y2_output_loss: 21.0637 - y2_output_mae: 3.3362 - val_loss: 21.9922 - val_y1_output_loss: 8.7874 - val_y1_output_mae: 2.0771 - val_y2_output_loss: 13.2861 - val_y2_output_mae: 2.4763
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.4317 - y1_output_loss: 18.6828 - y1_output_mae: 3.2068 - y2_output_loss: 21.4445 - y2_output_mae: 3.3989 - val_loss: 18.3447 - val_y1_output_loss: 7.9041 - val_y1_output_mae: 1.9313 - val_y2_output_loss: 10.3816 - val_y2_output_mae: 2.1729
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.1204 - y1_output_loss: 22.4688 - y1_output_mae: 3.4378 - y2_output_loss: 27.2029 - y2_output_mae: 3.7222 - val_loss: 19.3408 - val_y1_output_loss: 7.7397 - val_y1_output_mae: 1.9644 - val_y2_output_loss: 11.6312 - val_y2_output_mae: 2.2944
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.5620 - y1_output_loss: 19.6103 - y1_output_mae: 3.2966 - y2_output_loss: 24.6772 - y2_output_mae: 3.6593 - val_loss: 23.2744 - val_y1_output_loss: 9.7533 - val_y1_output_mae: 2.2480 - val_y2_output_loss: 13.5986 - val_y2_output_mae: 2.5429
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 47.3268 - y1_output_loss: 21.6411 - y1_output_mae: 3.4289 - y2_output_loss: 25.1150 - y2_output_mae: 3.7323 - val_loss: 27.4155 - val_y1_output_loss: 11.3735 - val_y1_output_mae: 2.5051 - val_y2_output_loss: 16.2235 - val_y2_output_mae: 2.8800
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 39.9126 - y1_output_loss: 17.4451 - y1_output_mae: 3.1423 - y2_output_loss: 21.8086 - y2_output_mae: 3.4062 - val_loss: 19.4019 - val_y1_output_loss: 7.7964 - val_y1_output_mae: 1.8930 - val_y2_output_loss: 11.6107 - val_y2_output_mae: 2.2723
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.5592 - y1_output_loss: 17.7441 - y1_output_mae: 3.0727 - y2_output_loss: 20.8427 - y2_output_mae: 3.4509 - val_loss: 21.4907 - val_y1_output_loss: 8.9477 - val_y1_output_mae: 2.1057 - val_y2_output_loss: 12.6763 - val_y2_output_mae: 2.3856
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.7571 - y1_output_loss: 19.0702 - y1_output_mae: 3.2324 - y2_output_loss: 21.1467 - y2_output_mae: 3.4623 - val_loss: 23.2574 - val_y1_output_loss: 9.1977 - val_y1_output_mae: 2.1965 - val_y2_output_loss: 14.1804 - val_y2_output_mae: 2.6480
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 37.7282 - y1_output_loss: 17.1393 - y1_output_mae: 3.0908 - y2_output_loss: 19.4164 - y2_output_mae: 3.3193 - val_loss: 21.6055 - val_y1_output_loss: 9.2022 - val_y1_output_mae: 2.1718 - val_y2_output_loss: 12.4539 - val_y2_output_mae: 2.4280
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.1003 - y1_output_loss: 16.3238 - y1_output_mae: 3.0059 - y2_output_loss: 18.6067 - y2_output_mae: 3.2513 - val_loss: 20.5361 - val_y1_output_loss: 7.7622 - val_y1_output_mae: 1.9807 - val_y2_output_loss: 12.8649 - val_y2_output_mae: 2.5085
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 40.4120 - y1_output_loss: 18.0940 - y1_output_mae: 3.0879 - y2_output_loss: 21.7312 - y2_output_mae: 3.5295 - val_loss: 18.7863 - val_y1_output_loss: 7.3445 - val_y1_output_mae: 1.9275 - val_y2_output_loss: 11.5284 - val_y2_output_mae: 2.3447
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.7144 - y1_output_loss: 19.9858 - y1_output_mae: 3.2164 - y2_output_loss: 20.4744 - y2_output_mae: 3.3490 - val_loss: 29.1237 - val_y1_output_loss: 11.4458 - val_y1_output_mae: 2.5418 - val_y2_output_loss: 17.9782 - val_y2_output_mae: 3.0772
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.1615 - y1_output_loss: 19.0999 - y1_output_mae: 3.2003 - y2_output_loss: 23.2060 - y2_output_mae: 3.4615 - val_loss: 19.9201 - val_y1_output_loss: 8.5450 - val_y1_output_mae: 2.1193 - val_y2_output_loss: 11.4436 - val_y2_output_mae: 2.3260
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.3280 - y1_output_loss: 19.4593 - y1_output_mae: 3.1743 - y2_output_loss: 23.2845 - y2_output_mae: 3.4988 - val_loss: 16.8734 - val_y1_output_loss: 6.9739 - val_y1_output_mae: 1.8517 - val_y2_output_loss: 9.9228 - val_y2_output_mae: 2.1332
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.1031 - y1_output_loss: 18.5365 - y1_output_mae: 3.1504 - y2_output_loss: 21.1249 - y2_output_mae: 3.4306 - val_loss: 19.0539 - val_y1_output_loss: 7.5655 - val_y1_output_mae: 1.9337 - val_y2_output_loss: 11.5401 - val_y2_output_mae: 2.3323
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 37.0169 - y1_output_loss: 15.6050 - y1_output_mae: 2.9163 - y2_output_loss: 20.8536 - y2_output_mae: 3.4454 - val_loss: 20.6453 - val_y1_output_loss: 8.0464 - val_y1_output_mae: 2.0520 - val_y2_output_loss: 12.6998 - val_y2_output_mae: 2.4972
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.0179 - y1_output_loss: 17.7164 - y1_output_mae: 3.1585 - y2_output_loss: 20.1680 - y2_output_mae: 3.3211 - val_loss: 20.4291 - val_y1_output_loss: 7.9095 - val_y1_output_mae: 2.0421 - val_y2_output_loss: 12.6394 - val_y2_output_mae: 2.4652
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.3361 - y1_output_loss: 18.4686 - y1_output_mae: 3.1221 - y2_output_loss: 23.0781 - y2_output_mae: 3.5454 - val_loss: 16.4532 - val_y1_output_loss: 6.5422 - val_y1_output_mae: 1.7325 - val_y2_output_loss: 9.9331 - val_y2_output_mae: 2.1168
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.4688 - y1_output_loss: 18.1315 - y1_output_mae: 3.0563 - y2_output_loss: 19.3582 - y2_output_mae: 3.3580 - val_loss: 14.0914 - val_y1_output_loss: 6.2319 - val_y1_output_mae: 1.7320 - val_y2_output_loss: 7.7928 - val_y2_output_mae: 2.0102
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.2889 - y1_output_loss: 17.3923 - y1_output_mae: 2.8640 - y2_output_loss: 19.1683 - y2_output_mae: 3.2427 - val_loss: 18.4534 - val_y1_output_loss: 6.4035 - val_y1_output_mae: 1.8188 - val_y2_output_loss: 12.1575 - val_y2_output_mae: 2.4668
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 39.4042 - y1_output_loss: 21.3417 - y1_output_mae: 3.2172 - y2_output_loss: 18.8893 - y2_output_mae: 3.2392 - val_loss: 18.5010 - val_y1_output_loss: 7.7650 - val_y1_output_mae: 2.1043 - val_y2_output_loss: 10.8577 - val_y2_output_mae: 2.3327
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.5580 - y1_output_loss: 15.0894 - y1_output_mae: 2.7893 - y2_output_loss: 20.1609 - y2_output_mae: 3.2668 - val_loss: 14.8978 - val_y1_output_loss: 6.1298 - val_y1_output_mae: 1.7068 - val_y2_output_loss: 8.7826 - val_y2_output_mae: 2.0352
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 35.7951 - y1_output_loss: 16.5394 - y1_output_mae: 2.9737 - y2_output_loss: 19.2639 - y2_output_mae: 3.2470 - val_loss: 20.3153 - val_y1_output_loss: 7.4386 - val_y1_output_mae: 2.0853 - val_y2_output_loss: 13.0935 - val_y2_output_mae: 2.6634
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.4235 - y1_output_loss: 15.1292 - y1_output_mae: 2.9880 - y2_output_loss: 17.9322 - y2_output_mae: 3.2539 - val_loss: 21.2570 - val_y1_output_loss: 7.9719 - val_y1_output_mae: 2.1318 - val_y2_output_loss: 13.5151 - val_y2_output_mae: 2.6140
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.7701 - y1_output_loss: 17.1457 - y1_output_mae: 2.9807 - y2_output_loss: 19.2248 - y2_output_mae: 3.2567 - val_loss: 20.1246 - val_y1_output_loss: 7.1905 - val_y1_output_mae: 1.9585 - val_y2_output_loss: 13.0909 - val_y2_output_mae: 2.5934
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.9123 - y1_output_loss: 15.8623 - y1_output_mae: 2.8597 - y2_output_loss: 19.3671 - y2_output_mae: 3.2934 - val_loss: 14.1009 - val_y1_output_loss: 5.9639 - val_y1_output_mae: 1.6598 - val_y2_output_loss: 8.1645 - val_y2_output_mae: 1.8920
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.6005 - y1_output_loss: 14.3501 - y1_output_mae: 2.7788 - y2_output_loss: 20.0018 - y2_output_mae: 3.2460 - val_loss: 18.0348 - val_y1_output_loss: 6.9596 - val_y1_output_mae: 1.9332 - val_y2_output_loss: 11.2494 - val_y2_output_mae: 2.3151
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.4052 - y1_output_loss: 17.9189 - y1_output_mae: 3.0791 - y2_output_loss: 16.4588 - y2_output_mae: 3.0203 - val_loss: 19.4267 - val_y1_output_loss: 7.2836 - val_y1_output_mae: 2.0290 - val_y2_output_loss: 12.3443 - val_y2_output_mae: 2.4809
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.2269 - y1_output_loss: 16.1332 - y1_output_mae: 2.9190 - y2_output_loss: 17.6526 - y2_output_mae: 3.1165 - val_loss: 23.9945 - val_y1_output_loss: 9.8913 - val_y1_output_mae: 2.3959 - val_y2_output_loss: 14.3913 - val_y2_output_mae: 2.6948
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.2623 - y1_output_loss: 16.5444 - y1_output_mae: 2.9979 - y2_output_loss: 20.7984 - y2_output_mae: 3.4315 - val_loss: 22.8197 - val_y1_output_loss: 8.1037 - val_y1_output_mae: 2.1891 - val_y2_output_loss: 14.8952 - val_y2_output_mae: 2.8889
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 31.0955 - y1_output_loss: 14.8414 - y1_output_mae: 2.7955 - y2_output_loss: 16.9481 - y2_output_mae: 2.9736 - val_loss: 15.0835 - val_y1_output_loss: 5.8749 - val_y1_output_mae: 1.7407 - val_y2_output_loss: 9.2689 - val_y2_output_mae: 2.0688
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.0238 - y1_output_loss: 15.1074 - y1_output_mae: 2.8535 - y2_output_loss: 17.1824 - y2_output_mae: 3.0541 - val_loss: 16.7524 - val_y1_output_loss: 5.8114 - val_y1_output_mae: 1.7457 - val_y2_output_loss: 11.0287 - val_y2_output_mae: 2.3672
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.3979 - y1_output_loss: 13.6424 - y1_output_mae: 2.7211 - y2_output_loss: 18.8375 - y2_output_mae: 3.1512 - val_loss: 16.9721 - val_y1_output_loss: 6.2414 - val_y1_output_mae: 1.8206 - val_y2_output_loss: 10.8417 - val_y2_output_mae: 2.3119
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.7267 - y1_output_loss: 15.2335 - y1_output_mae: 2.8417 - y2_output_loss: 17.6085 - y2_output_mae: 3.1764 - val_loss: 15.4795 - val_y1_output_loss: 5.3836 - val_y1_output_mae: 1.5661 - val_y2_output_loss: 10.1607 - val_y2_output_mae: 2.2367
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.0702 - y1_output_loss: 15.0656 - y1_output_mae: 2.7548 - y2_output_loss: 17.7980 - y2_output_mae: 3.2273 - val_loss: 14.4944 - val_y1_output_loss: 5.7845 - val_y1_output_mae: 1.7055 - val_y2_output_loss: 8.8088 - val_y2_output_mae: 1.9823
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.6387 - y1_output_loss: 15.5669 - y1_output_mae: 2.8810 - y2_output_loss: 18.5563 - y2_output_mae: 3.1567 - val_loss: 17.8442 - val_y1_output_loss: 6.2963 - val_y1_output_mae: 1.8440 - val_y2_output_loss: 11.7524 - val_y2_output_mae: 2.3506
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.3122 - y1_output_loss: 14.8913 - y1_output_mae: 2.8557 - y2_output_loss: 18.3401 - y2_output_mae: 3.0718 - val_loss: 15.9843 - val_y1_output_loss: 5.5251 - val_y1_output_mae: 1.6836 - val_y2_output_loss: 10.5915 - val_y2_output_mae: 2.2680
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.8288 - y1_output_loss: 15.9401 - y1_output_mae: 2.9090 - y2_output_loss: 18.6495 - y2_output_mae: 3.0599 - val_loss: 16.6633 - val_y1_output_loss: 5.7444 - val_y1_output_mae: 1.7559 - val_y2_output_loss: 11.0954 - val_y2_output_mae: 2.3326
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.9462 - y1_output_loss: 15.0658 - y1_output_mae: 2.8489 - y2_output_loss: 16.0825 - y2_output_mae: 2.9770 - val_loss: 15.5160 - val_y1_output_loss: 5.7588 - val_y1_output_mae: 1.7291 - val_y2_output_loss: 9.8680 - val_y2_output_mae: 2.1551
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.2044 - y1_output_loss: 14.6737 - y1_output_mae: 2.7720 - y2_output_loss: 15.1475 - y2_output_mae: 2.8692 - val_loss: 16.9904 - val_y1_output_loss: 6.2375 - val_y1_output_mae: 1.8802 - val_y2_output_loss: 10.9217 - val_y2_output_mae: 2.3613
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35.3477 - y1_output_loss: 16.4457 - y1_output_mae: 2.9052 - y2_output_loss: 17.9085 - y2_output_mae: 3.1995 - val_loss: 21.9478 - val_y1_output_loss: 7.0418 - val_y1_output_mae: 2.0722 - val_y2_output_loss: 15.1988 - val_y2_output_mae: 2.9240
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.6058 - y1_output_loss: 16.6118 - y1_output_mae: 2.8743 - y2_output_loss: 18.3714 - y2_output_mae: 2.9511 - val_loss: 14.9719 - val_y1_output_loss: 4.9850 - val_y1_output_mae: 1.4953 - val_y2_output_loss: 10.0901 - val_y2_output_mae: 2.2247
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.9044 - y1_output_loss: 14.4065 - y1_output_mae: 2.6850 - y2_output_loss: 16.9292 - y2_output_mae: 3.0511 - val_loss: 15.5884 - val_y1_output_loss: 5.4999 - val_y1_output_mae: 1.7347 - val_y2_output_loss: 10.2261 - val_y2_output_mae: 2.2402
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.3470 - y1_output_loss: 16.3855 - y1_output_mae: 2.9495 - y2_output_loss: 17.5150 - y2_output_mae: 3.0663 - val_loss: 16.8210 - val_y1_output_loss: 6.9317 - val_y1_output_mae: 1.9978 - val_y2_output_loss: 10.1042 - val_y2_output_mae: 2.1402
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.5009 - y1_output_loss: 13.7525 - y1_output_mae: 2.6774 - y2_output_loss: 15.3876 - y2_output_mae: 2.9141 - val_loss: 16.5461 - val_y1_output_loss: 5.8344 - val_y1_output_mae: 1.7643 - val_y2_output_loss: 10.8759 - val_y2_output_mae: 2.3089
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.4310 - y1_output_loss: 14.0378 - y1_output_mae: 2.7229 - y2_output_loss: 17.3907 - y2_output_mae: 3.0658 - val_loss: 13.8368 - val_y1_output_loss: 4.7636 - val_y1_output_mae: 1.5062 - val_y2_output_loss: 9.1408 - val_y2_output_mae: 2.0578
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.9297 - y1_output_loss: 14.4642 - y1_output_mae: 2.7834 - y2_output_loss: 14.7889 - y2_output_mae: 2.8933 - val_loss: 14.5385 - val_y1_output_loss: 5.1760 - val_y1_output_mae: 1.6219 - val_y2_output_loss: 9.4270 - val_y2_output_mae: 2.0949
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.4711 - y1_output_loss: 16.4841 - y1_output_mae: 2.9141 - y2_output_loss: 16.7433 - y2_output_mae: 2.9922 - val_loss: 22.3967 - val_y1_output_loss: 6.3457 - val_y1_output_mae: 1.8835 - val_y2_output_loss: 16.3433 - val_y2_output_mae: 3.0153
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.4423 - y1_output_loss: 16.3136 - y1_output_mae: 2.8618 - y2_output_loss: 16.7393 - y2_output_mae: 2.9861 - val_loss: 21.2386 - val_y1_output_loss: 6.9722 - val_y1_output_mae: 2.0248 - val_y2_output_loss: 14.5684 - val_y2_output_mae: 2.8035
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.7211 - y1_output_loss: 12.8673 - y1_output_mae: 2.6074 - y2_output_loss: 16.7934 - y2_output_mae: 2.9002 - val_loss: 16.2205 - val_y1_output_loss: 6.5886 - val_y1_output_mae: 1.9410 - val_y2_output_loss: 9.7796 - val_y2_output_mae: 2.1479
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 33.0058 - y1_output_loss: 15.2428 - y1_output_mae: 2.7518 - y2_output_loss: 19.1891 - y2_output_mae: 3.0809 - val_loss: 18.5428 - val_y1_output_loss: 5.1309 - val_y1_output_mae: 1.6630 - val_y2_output_loss: 13.6683 - val_y2_output_mae: 2.7051
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.4629 - y1_output_loss: 14.8976 - y1_output_mae: 2.7833 - y2_output_loss: 16.1523 - y2_output_mae: 2.8657 - val_loss: 14.5686 - val_y1_output_loss: 5.9357 - val_y1_output_mae: 1.7989 - val_y2_output_loss: 8.7809 - val_y2_output_mae: 1.9669
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 32.3835 - y1_output_loss: 13.9886 - y1_output_mae: 2.7219 - y2_output_loss: 18.0786 - y2_output_mae: 3.0348 - val_loss: 23.7531 - val_y1_output_loss: 7.4523 - val_y1_output_mae: 2.0525 - val_y2_output_loss: 16.6381 - val_y2_output_mae: 2.9630
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.1342 - y1_output_loss: 13.9075 - y1_output_mae: 2.7284 - y2_output_loss: 16.1237 - y2_output_mae: 2.9502 - val_loss: 16.6753 - val_y1_output_loss: 5.7255 - val_y1_output_mae: 1.7573 - val_y2_output_loss: 11.1291 - val_y2_output_mae: 2.3390
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.9368 - y1_output_loss: 14.9213 - y1_output_mae: 2.7544 - y2_output_loss: 16.3133 - y2_output_mae: 3.0122 - val_loss: 14.5979 - val_y1_output_loss: 4.7940 - val_y1_output_mae: 1.5349 - val_y2_output_loss: 9.9325 - val_y2_output_mae: 2.1760
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.0578 - y1_output_loss: 14.9572 - y1_output_mae: 2.7885 - y2_output_loss: 15.6536 - y2_output_mae: 2.8975 - val_loss: 14.7595 - val_y1_output_loss: 5.0018 - val_y1_output_mae: 1.6088 - val_y2_output_loss: 9.8845 - val_y2_output_mae: 2.1617
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.3949 - y1_output_loss: 14.1056 - y1_output_mae: 2.7497 - y2_output_loss: 15.9535 - y2_output_mae: 2.9307 - val_loss: 17.5413 - val_y1_output_loss: 4.7526 - val_y1_output_mae: 1.5447 - val_y2_output_loss: 13.0118 - val_y2_output_mae: 2.6025
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.4657 - y1_output_loss: 14.2835 - y1_output_mae: 2.7723 - y2_output_loss: 15.7738 - y2_output_mae: 2.8371 - val_loss: 15.4837 - val_y1_output_loss: 5.8001 - val_y1_output_mae: 1.8201 - val_y2_output_loss: 9.8352 - val_y2_output_mae: 2.1743
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.8315 - y1_output_loss: 13.3561 - y1_output_mae: 2.6994 - y2_output_loss: 14.6474 - y2_output_mae: 2.8982 - val_loss: 15.5704 - val_y1_output_loss: 5.0349 - val_y1_output_mae: 1.5943 - val_y2_output_loss: 10.6915 - val_y2_output_mae: 2.2607
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.2517 - y1_output_loss: 12.5167 - y1_output_mae: 2.5057 - y2_output_loss: 14.8296 - y2_output_mae: 2.8197 - val_loss: 15.8994 - val_y1_output_loss: 4.8998 - val_y1_output_mae: 1.5884 - val_y2_output_loss: 11.2000 - val_y2_output_mae: 2.3657
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.3655 - y1_output_loss: 12.1369 - y1_output_mae: 2.4758 - y2_output_loss: 14.9245 - y2_output_mae: 2.8138 - val_loss: 14.7313 - val_y1_output_loss: 4.9755 - val_y1_output_mae: 1.5843 - val_y2_output_loss: 9.8988 - val_y2_output_mae: 2.1260
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.5128 - y1_output_loss: 11.5531 - y1_output_mae: 2.5670 - y2_output_loss: 14.8741 - y2_output_mae: 2.9191 - val_loss: 23.5326 - val_y1_output_loss: 5.8549 - val_y1_output_mae: 1.8333 - val_y2_output_loss: 17.9630 - val_y2_output_mae: 3.2476
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.3601 - y1_output_loss: 12.9779 - y1_output_mae: 2.6092 - y2_output_loss: 14.8393 - y2_output_mae: 2.8036 - val_loss: 14.1789 - val_y1_output_loss: 4.9824 - val_y1_output_mae: 1.5945 - val_y2_output_loss: 9.3331 - val_y2_output_mae: 2.0789
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.9486 - y1_output_loss: 13.6292 - y1_output_mae: 2.7064 - y2_output_loss: 13.8583 - y2_output_mae: 2.7200 - val_loss: 18.5965 - val_y1_output_loss: 6.5581 - val_y1_output_mae: 1.9519 - val_y2_output_loss: 12.3220 - val_y2_output_mae: 2.4950
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.1211 - y1_output_loss: 14.2892 - y1_output_mae: 2.7800 - y2_output_loss: 16.2162 - y2_output_mae: 3.0037 - val_loss: 17.1721 - val_y1_output_loss: 5.1633 - val_y1_output_mae: 1.7105 - val_y2_output_loss: 12.2229 - val_y2_output_mae: 2.5691
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.0525 - y1_output_loss: 13.6748 - y1_output_mae: 2.6438 - y2_output_loss: 15.6313 - y2_output_mae: 2.9453 - val_loss: 10.5806 - val_y1_output_loss: 4.2766 - val_y1_output_mae: 1.3511 - val_y2_output_loss: 6.2665 - val_y2_output_mae: 1.6532
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.2466 - y1_output_loss: 15.0847 - y1_output_mae: 2.8467 - y2_output_loss: 13.9042 - y2_output_mae: 2.7459 - val_loss: 14.1562 - val_y1_output_loss: 4.2447 - val_y1_output_mae: 1.5006 - val_y2_output_loss: 10.0313 - val_y2_output_mae: 2.1630
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.7770 - y1_output_loss: 12.1453 - y1_output_mae: 2.5620 - y2_output_loss: 14.0995 - y2_output_mae: 2.7676 - val_loss: 16.7840 - val_y1_output_loss: 5.3160 - val_y1_output_mae: 1.6963 - val_y2_output_loss: 11.7073 - val_y2_output_mae: 2.3664
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.5206 - y1_output_loss: 12.9066 - y1_output_mae: 2.5718 - y2_output_loss: 14.3027 - y2_output_mae: 2.7154 - val_loss: 15.0954 - val_y1_output_loss: 4.8561 - val_y1_output_mae: 1.6221 - val_y2_output_loss: 10.4282 - val_y2_output_mae: 2.2594
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.5292 - y1_output_loss: 13.4120 - y1_output_mae: 2.6434 - y2_output_loss: 16.5720 - y2_output_mae: 2.8448 - val_loss: 19.8795 - val_y1_output_loss: 6.0378 - val_y1_output_mae: 1.8518 - val_y2_output_loss: 14.1662 - val_y2_output_mae: 2.7230
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.8535 - y1_output_loss: 11.5508 - y1_output_mae: 2.5304 - y2_output_loss: 13.7426 - y2_output_mae: 2.7698 - val_loss: 17.7510 - val_y1_output_loss: 5.0889 - val_y1_output_mae: 1.6955 - val_y2_output_loss: 12.9243 - val_y2_output_mae: 2.6246
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.4263 - y1_output_loss: 12.1057 - y1_output_mae: 2.5600 - y2_output_loss: 13.4288 - y2_output_mae: 2.7517 - val_loss: 16.7146 - val_y1_output_loss: 5.5092 - val_y1_output_mae: 1.7399 - val_y2_output_loss: 11.4254 - val_y2_output_mae: 2.3644
# Epoch 109/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.3077 - y1_output_loss: 12.5131 - y1_output_mae: 2.5303 - y2_output_loss: 15.0669 - y2_output_mae: 2.7541 - val_loss: 11.0284 - val_y1_output_loss: 3.9833 - val_y1_output_mae: 1.3480 - val_y2_output_loss: 7.0837 - val_y2_output_mae: 1.6963
# Epoch 110/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.8285 - y1_output_loss: 12.1714 - y1_output_mae: 2.5425 - y2_output_loss: 15.1059 - y2_output_mae: 2.8601 - val_loss: 11.3118 - val_y1_output_loss: 3.9778 - val_y1_output_mae: 1.3657 - val_y2_output_loss: 7.3590 - val_y2_output_mae: 1.7116
# Epoch 111/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.7959 - y1_output_loss: 13.1465 - y1_output_mae: 2.5555 - y2_output_loss: 13.7066 - y2_output_mae: 2.6879 - val_loss: 16.7008 - val_y1_output_loss: 5.3095 - val_y1_output_mae: 1.7042 - val_y2_output_loss: 11.6479 - val_y2_output_mae: 2.3548
# Epoch 112/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.3345 - y1_output_loss: 15.0034 - y1_output_mae: 2.7918 - y2_output_loss: 13.6099 - y2_output_mae: 2.7861 - val_loss: 20.9282 - val_y1_output_loss: 5.4754 - val_y1_output_mae: 1.7307 - val_y2_output_loss: 15.7502 - val_y2_output_mae: 2.9092
# Epoch 113/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.9840 - y1_output_loss: 13.0436 - y1_output_mae: 2.5895 - y2_output_loss: 12.6746 - y2_output_mae: 2.6722 - val_loss: 19.2974 - val_y1_output_loss: 6.3235 - val_y1_output_mae: 1.8544 - val_y2_output_loss: 13.2391 - val_y2_output_mae: 2.5455
# Epoch 114/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.8848 - y1_output_loss: 12.3276 - y1_output_mae: 2.5167 - y2_output_loss: 12.8098 - y2_output_mae: 2.5907 - val_loss: 17.1886 - val_y1_output_loss: 4.9525 - val_y1_output_mae: 1.6572 - val_y2_output_loss: 12.4519 - val_y2_output_mae: 2.5109
# Epoch 115/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.4569 - y1_output_loss: 12.2085 - y1_output_mae: 2.4698 - y2_output_loss: 15.2387 - y2_output_mae: 2.8338 - val_loss: 13.9571 - val_y1_output_loss: 3.9890 - val_y1_output_mae: 1.3607 - val_y2_output_loss: 10.1267 - val_y2_output_mae: 2.2281
# Epoch 116/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.5045 - y1_output_loss: 13.5920 - y1_output_mae: 2.7199 - y2_output_loss: 11.6275 - y2_output_mae: 2.5342 - val_loss: 16.8737 - val_y1_output_loss: 5.7929 - val_y1_output_mae: 1.8742 - val_y2_output_loss: 11.3012 - val_y2_output_mae: 2.4239
# Epoch 117/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.9694 - y1_output_loss: 11.0551 - y1_output_mae: 2.4491 - y2_output_loss: 13.4270 - y2_output_mae: 2.6986 - val_loss: 15.4729 - val_y1_output_loss: 4.2534 - val_y1_output_mae: 1.5109 - val_y2_output_loss: 11.4060 - val_y2_output_mae: 2.4163
# Epoch 118/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.0791 - y1_output_loss: 12.3362 - y1_output_mae: 2.4647 - y2_output_loss: 13.3301 - y2_output_mae: 2.5411 - val_loss: 18.0497 - val_y1_output_loss: 5.6233 - val_y1_output_mae: 1.9013 - val_y2_output_loss: 12.6691 - val_y2_output_mae: 2.6681
# Epoch 119/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.1104 - y1_output_loss: 15.2203 - y1_output_mae: 2.7444 - y2_output_loss: 15.6101 - y2_output_mae: 2.8123 - val_loss: 16.5762 - val_y1_output_loss: 4.5017 - val_y1_output_mae: 1.5966 - val_y2_output_loss: 12.2604 - val_y2_output_mae: 2.5072
# Epoch 120/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 26.3957 - y1_output_loss: 11.4086 - y1_output_mae: 2.5234 - y2_output_loss: 14.8645 - y2_output_mae: 2.7416 - val_loss: 16.0969 - val_y1_output_loss: 3.9155 - val_y1_output_mae: 1.4165 - val_y2_output_loss: 12.3566 - val_y2_output_mae: 2.5463
# Epoch 121/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.0235 - y1_output_loss: 12.5653 - y1_output_mae: 2.5939 - y2_output_loss: 14.5118 - y2_output_mae: 2.7213 - val_loss: 12.8368 - val_y1_output_loss: 4.7788 - val_y1_output_mae: 1.6473 - val_y2_output_loss: 8.1419 - val_y2_output_mae: 1.8910
# Epoch 122/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.0207 - y1_output_loss: 13.0647 - y1_output_mae: 2.6072 - y2_output_loss: 15.0421 - y2_output_mae: 2.7917 - val_loss: 17.0716 - val_y1_output_loss: 3.9946 - val_y1_output_mae: 1.4655 - val_y2_output_loss: 13.2941 - val_y2_output_mae: 2.6364
# Epoch 123/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.0368 - y1_output_loss: 12.9608 - y1_output_mae: 2.5746 - y2_output_loss: 14.2518 - y2_output_mae: 2.7324 - val_loss: 18.5116 - val_y1_output_loss: 5.5752 - val_y1_output_mae: 1.8070 - val_y2_output_loss: 13.2435 - val_y2_output_mae: 2.6497
# Epoch 124/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.6035 - y1_output_loss: 11.9524 - y1_output_mae: 2.5195 - y2_output_loss: 11.1954 - y2_output_mae: 2.4580 - val_loss: 16.8175 - val_y1_output_loss: 5.1252 - val_y1_output_mae: 1.6967 - val_y2_output_loss: 11.9576 - val_y2_output_mae: 2.4557
# Epoch 125/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.7304 - y1_output_loss: 11.6005 - y1_output_mae: 2.4698 - y2_output_loss: 13.6193 - y2_output_mae: 2.5582 - val_loss: 17.5984 - val_y1_output_loss: 4.8190 - val_y1_output_mae: 1.7114 - val_y2_output_loss: 13.0290 - val_y2_output_mae: 2.7233
# Epoch 126/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.5280 - y1_output_loss: 12.3464 - y1_output_mae: 2.4842 - y2_output_loss: 12.7438 - y2_output_mae: 2.5728 - val_loss: 19.6909 - val_y1_output_loss: 3.9427 - val_y1_output_mae: 1.4662 - val_y2_output_loss: 16.0369 - val_y2_output_mae: 2.9740
# Epoch 127/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.2338 - y1_output_loss: 13.1140 - y1_output_mae: 2.4619 - y2_output_loss: 13.5222 - y2_output_mae: 2.6629 - val_loss: 27.1267 - val_y1_output_loss: 6.8792 - val_y1_output_mae: 2.0573 - val_y2_output_loss: 20.7222 - val_y2_output_mae: 3.5067
# Epoch 128/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.4933 - y1_output_loss: 12.8366 - y1_output_mae: 2.5832 - y2_output_loss: 13.1429 - y2_output_mae: 2.7153 - val_loss: 21.6851 - val_y1_output_loss: 4.7914 - val_y1_output_mae: 1.6321 - val_y2_output_loss: 17.2595 - val_y2_output_mae: 3.0909
# Epoch 129/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.6414 - y1_output_loss: 10.2592 - y1_output_mae: 2.3281 - y2_output_loss: 12.3188 - y2_output_mae: 2.5269 - val_loss: 20.6317 - val_y1_output_loss: 7.3545 - val_y1_output_mae: 2.0646 - val_y2_output_loss: 13.6187 - val_y2_output_mae: 2.6564
# Epoch 130/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.6996 - y1_output_loss: 11.6035 - y1_output_mae: 2.4177 - y2_output_loss: 13.6961 - y2_output_mae: 2.7333 - val_loss: 19.9594 - val_y1_output_loss: 5.6894 - val_y1_output_mae: 1.8129 - val_y2_output_loss: 14.5864 - val_y2_output_mae: 2.7820
# Epoch 131/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.8169 - y1_output_loss: 11.8529 - y1_output_mae: 2.4081 - y2_output_loss: 11.6158 - y2_output_mae: 2.5464 - val_loss: 18.8697 - val_y1_output_loss: 5.5657 - val_y1_output_mae: 1.8516 - val_y2_output_loss: 13.6383 - val_y2_output_mae: 2.7024
# Epoch 132/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.6241 - y1_output_loss: 12.7215 - y1_output_mae: 2.5664 - y2_output_loss: 12.2370 - y2_output_mae: 2.4797 - val_loss: 18.9419 - val_y1_output_loss: 4.1850 - val_y1_output_mae: 1.5451 - val_y2_output_loss: 15.0332 - val_y2_output_mae: 2.8480
# Epoch 133/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.1815 - y1_output_loss: 11.3050 - y1_output_mae: 2.3744 - y2_output_loss: 14.2660 - y2_output_mae: 2.7131 - val_loss: 19.0986 - val_y1_output_loss: 4.9774 - val_y1_output_mae: 1.7083 - val_y2_output_loss: 14.4410 - val_y2_output_mae: 2.7474
# Epoch 134/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.5732 - y1_output_loss: 12.7987 - y1_output_mae: 2.5124 - y2_output_loss: 13.8327 - y2_output_mae: 2.6074 - val_loss: 20.7162 - val_y1_output_loss: 6.8739 - val_y1_output_mae: 2.0221 - val_y2_output_loss: 14.2097 - val_y2_output_mae: 2.7448
# Epoch 135/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.3997 - y1_output_loss: 12.1780 - y1_output_mae: 2.5121 - y2_output_loss: 11.1133 - y2_output_mae: 2.4007 - val_loss: 15.5200 - val_y1_output_loss: 3.8386 - val_y1_output_mae: 1.4240 - val_y2_output_loss: 11.9231 - val_y2_output_mae: 2.4849
# Epoch 136/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.9099 - y1_output_loss: 10.6240 - y1_output_mae: 2.3526 - y2_output_loss: 11.5020 - y2_output_mae: 2.5196 - val_loss: 16.5360 - val_y1_output_loss: 4.4222 - val_y1_output_mae: 1.5519 - val_y2_output_loss: 12.3717 - val_y2_output_mae: 2.5037
# Epoch 137/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.5993 - y1_output_loss: 10.8120 - y1_output_mae: 2.3762 - y2_output_loss: 12.4803 - y2_output_mae: 2.4950 - val_loss: 20.6256 - val_y1_output_loss: 5.4220 - val_y1_output_mae: 1.7712 - val_y2_output_loss: 15.5142 - val_y2_output_mae: 2.8962
# Epoch 138/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.9865 - y1_output_loss: 10.1179 - y1_output_mae: 2.2891 - y2_output_loss: 10.5163 - y2_output_mae: 2.3953 - val_loss: 15.7215 - val_y1_output_loss: 4.0062 - val_y1_output_mae: 1.4774 - val_y2_output_loss: 11.9131 - val_y2_output_mae: 2.4560
# Epoch 139/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.4795 - y1_output_loss: 12.0506 - y1_output_mae: 2.3670 - y2_output_loss: 11.5577 - y2_output_mae: 2.5050 - val_loss: 22.3771 - val_y1_output_loss: 5.9789 - val_y1_output_mae: 1.8413 - val_y2_output_loss: 16.8663 - val_y2_output_mae: 3.0339
# Epoch 140/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.5034 - y1_output_loss: 10.3238 - y1_output_mae: 2.3233 - y2_output_loss: 12.3899 - y2_output_mae: 2.5193 - val_loss: 11.7999 - val_y1_output_loss: 3.4644 - val_y1_output_mae: 1.2701 - val_y2_output_loss: 8.4922 - val_y2_output_mae: 1.9344
# Epoch 141/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.7363 - y1_output_loss: 12.1920 - y1_output_mae: 2.4785 - y2_output_loss: 13.6339 - y2_output_mae: 2.6110 - val_loss: 12.1973 - val_y1_output_loss: 3.3567 - val_y1_output_mae: 1.2924 - val_y2_output_loss: 8.9948 - val_y2_output_mae: 2.0129
# Epoch 142/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 22.0972 - y1_output_loss: 10.7755 - y1_output_mae: 2.3459 - y2_output_loss: 11.0140 - y2_output_mae: 2.4180 - val_loss: 15.1436 - val_y1_output_loss: 3.3903 - val_y1_output_mae: 1.3038 - val_y2_output_loss: 11.9542 - val_y2_output_mae: 2.4689
# Epoch 143/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.4427 - y1_output_loss: 12.3428 - y1_output_mae: 2.3814 - y2_output_loss: 11.8921 - y2_output_mae: 2.3801 - val_loss: 15.7252 - val_y1_output_loss: 3.9385 - val_y1_output_mae: 1.5002 - val_y2_output_loss: 12.0651 - val_y2_output_mae: 2.4077
# Epoch 144/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.0438 - y1_output_loss: 10.7102 - y1_output_mae: 2.3519 - y2_output_loss: 10.8640 - y2_output_mae: 2.4334 - val_loss: 15.6381 - val_y1_output_loss: 3.3467 - val_y1_output_mae: 1.3185 - val_y2_output_loss: 12.5807 - val_y2_output_mae: 2.5141
# Epoch 145/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.0816 - y1_output_loss: 11.2613 - y1_output_mae: 2.4010 - y2_output_loss: 11.4583 - y2_output_mae: 2.4014 - val_loss: 15.3197 - val_y1_output_loss: 4.3431 - val_y1_output_mae: 1.5429 - val_y2_output_loss: 11.2923 - val_y2_output_mae: 2.2808
# Epoch 146/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.2180 - y1_output_loss: 9.9527 - y1_output_mae: 2.2229 - y2_output_loss: 11.2933 - y2_output_mae: 2.3922 - val_loss: 16.0136 - val_y1_output_loss: 4.0307 - val_y1_output_mae: 1.5462 - val_y2_output_loss: 12.2862 - val_y2_output_mae: 2.4863
# Epoch 147/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.7520 - y1_output_loss: 10.6253 - y1_output_mae: 2.2718 - y2_output_loss: 10.5786 - y2_output_mae: 2.3756 - val_loss: 26.2839 - val_y1_output_loss: 5.4294 - val_y1_output_mae: 1.8285 - val_y2_output_loss: 21.3310 - val_y2_output_mae: 3.5274
# Epoch 148/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.6085 - y1_output_loss: 10.9881 - y1_output_mae: 2.3595 - y2_output_loss: 12.5581 - y2_output_mae: 2.4861 - val_loss: 18.8434 - val_y1_output_loss: 6.2788 - val_y1_output_mae: 1.8871 - val_y2_output_loss: 12.9328 - val_y2_output_mae: 2.5356
# Epoch 149/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.0623 - y1_output_loss: 11.8662 - y1_output_mae: 2.4427 - y2_output_loss: 13.1730 - y2_output_mae: 2.4767 - val_loss: 18.4125 - val_y1_output_loss: 4.7557 - val_y1_output_mae: 1.5903 - val_y2_output_loss: 14.0549 - val_y2_output_mae: 2.6554
# Epoch 150/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.8512 - y1_output_loss: 9.7297 - y1_output_mae: 2.2318 - y2_output_loss: 10.9442 - y2_output_mae: 2.3948 - val_loss: 16.5354 - val_y1_output_loss: 3.0949 - val_y1_output_mae: 1.2041 - val_y2_output_loss: 13.6925 - val_y2_output_mae: 2.7459
# Epoch 151/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.5475 - y1_output_loss: 9.9041 - y1_output_mae: 2.2243 - y2_output_loss: 11.2418 - y2_output_mae: 2.4149 - val_loss: 13.4748 - val_y1_output_loss: 3.5956 - val_y1_output_mae: 1.4255 - val_y2_output_loss: 10.1156 - val_y2_output_mae: 2.1596
# Epoch 152/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.3864 - y1_output_loss: 10.5520 - y1_output_mae: 2.2773 - y2_output_loss: 10.3505 - y2_output_mae: 2.3801 - val_loss: 17.0644 - val_y1_output_loss: 3.5176 - val_y1_output_mae: 1.3893 - val_y2_output_loss: 13.9076 - val_y2_output_mae: 2.6639
# Epoch 153/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.4258 - y1_output_loss: 9.5864 - y1_output_mae: 2.2184 - y2_output_loss: 10.6234 - y2_output_mae: 2.3082 - val_loss: 14.4699 - val_y1_output_loss: 4.0559 - val_y1_output_mae: 1.4935 - val_y2_output_loss: 10.7229 - val_y2_output_mae: 2.2471
# Epoch 154/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.0778 - y1_output_loss: 9.8469 - y1_output_mae: 2.2689 - y2_output_loss: 11.0285 - y2_output_mae: 2.3862 - val_loss: 19.5911 - val_y1_output_loss: 3.0141 - val_y1_output_mae: 1.2612 - val_y2_output_loss: 16.9458 - val_y2_output_mae: 2.9705
# Epoch 155/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.4222 - y1_output_loss: 10.8210 - y1_output_mae: 2.3827 - y2_output_loss: 9.5205 - y2_output_mae: 2.2357 - val_loss: 22.9577 - val_y1_output_loss: 6.6911 - val_y1_output_mae: 1.9662 - val_y2_output_loss: 16.7192 - val_y2_output_mae: 2.9064
# Epoch 156/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.6935 - y1_output_loss: 9.5519 - y1_output_mae: 2.2322 - y2_output_loss: 11.2402 - y2_output_mae: 2.4241 - val_loss: 17.7814 - val_y1_output_loss: 3.4386 - val_y1_output_mae: 1.3795 - val_y2_output_loss: 14.6910 - val_y2_output_mae: 2.7713
# Epoch 157/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.9691 - y1_output_loss: 9.9674 - y1_output_mae: 2.2629 - y2_output_loss: 11.3503 - y2_output_mae: 2.3560 - val_loss: 22.3398 - val_y1_output_loss: 5.8073 - val_y1_output_mae: 1.7969 - val_y2_output_loss: 16.9541 - val_y2_output_mae: 2.9289
# Epoch 158/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.9053 - y1_output_loss: 9.9976 - y1_output_mae: 2.2862 - y2_output_loss: 10.3345 - y2_output_mae: 2.3346 - val_loss: 17.8407 - val_y1_output_loss: 4.0745 - val_y1_output_mae: 1.5220 - val_y2_output_loss: 14.1107 - val_y2_output_mae: 2.6679
# Epoch 159/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.5836 - y1_output_loss: 8.9276 - y1_output_mae: 2.1157 - y2_output_loss: 10.4669 - y2_output_mae: 2.3439 - val_loss: 21.4901 - val_y1_output_loss: 3.3938 - val_y1_output_mae: 1.3453 - val_y2_output_loss: 18.5230 - val_y2_output_mae: 3.1481
# Epoch 160/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.9989 - y1_output_loss: 9.8830 - y1_output_mae: 2.2204 - y2_output_loss: 9.2369 - y2_output_mae: 2.1925 - val_loss: 19.4736 - val_y1_output_loss: 5.6461 - val_y1_output_mae: 1.8041 - val_y2_output_loss: 14.2350 - val_y2_output_mae: 2.6662
# Epoch 161/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.9281 - y1_output_loss: 9.3414 - y1_output_mae: 2.1856 - y2_output_loss: 11.3609 - y2_output_mae: 2.3136 - val_loss: 13.4910 - val_y1_output_loss: 2.7090 - val_y1_output_mae: 1.2047 - val_y2_output_loss: 11.0166 - val_y2_output_mae: 2.3442
# Epoch 162/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.5978 - y1_output_loss: 9.3864 - y1_output_mae: 2.2177 - y2_output_loss: 10.9586 - y2_output_mae: 2.2993 - val_loss: 20.8249 - val_y1_output_loss: 4.1209 - val_y1_output_mae: 1.4846 - val_y2_output_loss: 17.1496 - val_y2_output_mae: 3.0064
# Epoch 163/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.3581 - y1_output_loss: 9.1904 - y1_output_mae: 2.0962 - y2_output_loss: 10.7399 - y2_output_mae: 2.3070 - val_loss: 18.6192 - val_y1_output_loss: 4.0757 - val_y1_output_mae: 1.5012 - val_y2_output_loss: 14.9628 - val_y2_output_mae: 2.7596
# Epoch 164/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.8142 - y1_output_loss: 8.1319 - y1_output_mae: 2.0694 - y2_output_loss: 10.3510 - y2_output_mae: 2.2582 - val_loss: 21.0434 - val_y1_output_loss: 4.5614 - val_y1_output_mae: 1.5907 - val_y2_output_loss: 16.9257 - val_y2_output_mae: 2.9394
# Epoch 165/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.9663 - y1_output_loss: 9.1754 - y1_output_mae: 2.1944 - y2_output_loss: 9.1968 - y2_output_mae: 2.1471 - val_loss: 18.1665 - val_y1_output_loss: 5.0251 - val_y1_output_mae: 1.6751 - val_y2_output_loss: 13.5229 - val_y2_output_mae: 2.5865
# Epoch 166/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.0598 - y1_output_loss: 8.9935 - y1_output_mae: 2.1634 - y2_output_loss: 9.7662 - y2_output_mae: 2.2319 - val_loss: 22.7138 - val_y1_output_loss: 4.7077 - val_y1_output_mae: 1.6014 - val_y2_output_loss: 18.5088 - val_y2_output_mae: 3.1943
# Epoch 167/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.8198 - y1_output_loss: 8.5196 - y1_output_mae: 2.0411 - y2_output_loss: 10.4318 - y2_output_mae: 2.3199 - val_loss: 21.4299 - val_y1_output_loss: 3.8214 - val_y1_output_mae: 1.4515 - val_y2_output_loss: 18.0428 - val_y2_output_mae: 3.1090
# Epoch 168/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.0872 - y1_output_loss: 9.0373 - y1_output_mae: 2.1183 - y2_output_loss: 10.7021 - y2_output_mae: 2.3243 - val_loss: 16.4225 - val_y1_output_loss: 5.2829 - val_y1_output_mae: 1.7812 - val_y2_output_loss: 11.4914 - val_y2_output_mae: 2.3503
# Epoch 169/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.8675 - y1_output_loss: 9.9427 - y1_output_mae: 2.2046 - y2_output_loss: 11.0395 - y2_output_mae: 2.3699 - val_loss: 17.3163 - val_y1_output_loss: 4.5437 - val_y1_output_mae: 1.5975 - val_y2_output_loss: 13.1111 - val_y2_output_mae: 2.6040
# Epoch 170/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.5564 - y1_output_loss: 8.7977 - y1_output_mae: 2.0583 - y2_output_loss: 10.9182 - y2_output_mae: 2.3449 - val_loss: 22.1102 - val_y1_output_loss: 5.3401 - val_y1_output_mae: 1.7132 - val_y2_output_loss: 17.2208 - val_y2_output_mae: 3.0229
# Epoch 171/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.9592 - y1_output_loss: 9.8805 - y1_output_mae: 2.1946 - y2_output_loss: 9.2347 - y2_output_mae: 2.1991 - val_loss: 21.5254 - val_y1_output_loss: 5.2441 - val_y1_output_mae: 1.7511 - val_y2_output_loss: 16.7121 - val_y2_output_mae: 3.0097
# Epoch 172/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.5649 - y1_output_loss: 9.4790 - y1_output_mae: 2.1181 - y2_output_loss: 9.7187 - y2_output_mae: 2.3054 - val_loss: 21.1691 - val_y1_output_loss: 3.6332 - val_y1_output_mae: 1.4112 - val_y2_output_loss: 17.9230 - val_y2_output_mae: 3.1366
# Epoch 173/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 19.2205 - y1_output_loss: 9.4534 - y1_output_mae: 2.0948 - y2_output_loss: 10.8980 - y2_output_mae: 2.3035 - val_loss: 24.4819 - val_y1_output_loss: 6.7558 - val_y1_output_mae: 1.9055 - val_y2_output_loss: 18.2814 - val_y2_output_mae: 3.0805
# Epoch 174/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.3005 - y1_output_loss: 9.0309 - y1_output_mae: 2.1657 - y2_output_loss: 9.3264 - y2_output_mae: 2.1781 - val_loss: 27.3615 - val_y1_output_loss: 6.5152 - val_y1_output_mae: 1.8497 - val_y2_output_loss: 21.3962 - val_y2_output_mae: 3.4039
# Epoch 175/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.2901 - y1_output_loss: 9.4862 - y1_output_mae: 2.1786 - y2_output_loss: 11.0083 - y2_output_mae: 2.2190 - val_loss: 25.0657 - val_y1_output_loss: 4.5249 - val_y1_output_mae: 1.5831 - val_y2_output_loss: 21.0850 - val_y2_output_mae: 3.4226
# Epoch 176/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.5447 - y1_output_loss: 9.2905 - y1_output_mae: 2.1455 - y2_output_loss: 9.7661 - y2_output_mae: 2.3188 - val_loss: 18.9329 - val_y1_output_loss: 5.5848 - val_y1_output_mae: 1.7987 - val_y2_output_loss: 13.7409 - val_y2_output_mae: 2.6296
# Epoch 177/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.8566 - y1_output_loss: 7.8600 - y1_output_mae: 2.0891 - y2_output_loss: 8.6425 - y2_output_mae: 2.1252 - val_loss: 20.4217 - val_y1_output_loss: 2.3136 - val_y1_output_mae: 1.0989 - val_y2_output_loss: 18.5432 - val_y2_output_mae: 3.2271
# Epoch 178/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.1927 - y1_output_loss: 8.6412 - y1_output_mae: 2.1044 - y2_output_loss: 8.4651 - y2_output_mae: 2.1507 - val_loss: 13.3166 - val_y1_output_loss: 2.5524 - val_y1_output_mae: 1.1535 - val_y2_output_loss: 11.0796 - val_y2_output_mae: 2.2711
# Epoch 179/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.8991 - y1_output_loss: 8.4208 - y1_output_mae: 2.0887 - y2_output_loss: 9.4266 - y2_output_mae: 2.1223 - val_loss: 18.9736 - val_y1_output_loss: 2.6716 - val_y1_output_mae: 1.1650 - val_y2_output_loss: 16.6737 - val_y2_output_mae: 2.9411
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.6469 - y1_output_loss: 9.0211 - y1_output_mae: 2.1288 - y2_output_loss: 10.2305 - y2_output_mae: 2.3174 - val_loss: 15.7780 - val_y1_output_loss: 4.1507 - val_y1_output_mae: 1.5635 - val_y2_output_loss: 11.9285 - val_y2_output_mae: 2.3770
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.7610 - y1_output_loss: 7.3950 - y1_output_mae: 1.9836 - y2_output_loss: 9.9910 - y2_output_mae: 2.3400 - val_loss: 22.8302 - val_y1_output_loss: 3.6204 - val_y1_output_mae: 1.4001 - val_y2_output_loss: 19.6964 - val_y2_output_mae: 3.2387
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.8533 - y1_output_loss: 8.4819 - y1_output_mae: 2.0476 - y2_output_loss: 10.2808 - y2_output_mae: 2.1801 - val_loss: 12.9747 - val_y1_output_loss: 2.5224 - val_y1_output_mae: 1.2043 - val_y2_output_loss: 10.7629 - val_y2_output_mae: 2.2535
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.2527 - y1_output_loss: 8.1505 - y1_output_mae: 2.0510 - y2_output_loss: 9.6633 - y2_output_mae: 2.2309 - val_loss: 16.9641 - val_y1_output_loss: 2.9638 - val_y1_output_mae: 1.2499 - val_y2_output_loss: 14.4037 - val_y2_output_mae: 2.7065
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.0031 - y1_output_loss: 8.1937 - y1_output_mae: 2.0334 - y2_output_loss: 8.7393 - y2_output_mae: 2.1408 - val_loss: 15.7071 - val_y1_output_loss: 2.5148 - val_y1_output_mae: 1.1663 - val_y2_output_loss: 13.5019 - val_y2_output_mae: 2.6192
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.4013 - y1_output_loss: 8.2687 - y1_output_mae: 2.0566 - y2_output_loss: 9.7780 - y2_output_mae: 2.2124 - val_loss: 22.0325 - val_y1_output_loss: 4.3316 - val_y1_output_mae: 1.5467 - val_y2_output_loss: 18.2134 - val_y2_output_mae: 3.0942
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.0020 - y1_output_loss: 7.9939 - y1_output_mae: 2.0431 - y2_output_loss: 8.9047 - y2_output_mae: 2.1050 - val_loss: 18.9426 - val_y1_output_loss: 4.1082 - val_y1_output_mae: 1.5491 - val_y2_output_loss: 15.2717 - val_y2_output_mae: 2.7853
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.7695 - y1_output_loss: 7.9335 - y1_output_mae: 2.0264 - y2_output_loss: 8.4576 - y2_output_mae: 2.0674 - val_loss: 21.1429 - val_y1_output_loss: 3.5272 - val_y1_output_mae: 1.4014 - val_y2_output_loss: 18.1050 - val_y2_output_mae: 3.1255
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.1513 - y1_output_loss: 10.7540 - y1_output_mae: 2.1234 - y2_output_loss: 9.5822 - y2_output_mae: 2.1805 - val_loss: 23.1873 - val_y1_output_loss: 3.4748 - val_y1_output_mae: 1.3761 - val_y2_output_loss: 20.2465 - val_y2_output_mae: 3.3298
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.9727 - y1_output_loss: 9.5950 - y1_output_mae: 2.1194 - y2_output_loss: 8.0698 - y2_output_mae: 2.0059 - val_loss: 15.5333 - val_y1_output_loss: 3.2092 - val_y1_output_mae: 1.3464 - val_y2_output_loss: 12.6546 - val_y2_output_mae: 2.5285
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.3937 - y1_output_loss: 8.0365 - y1_output_mae: 2.0267 - y2_output_loss: 8.3468 - y2_output_mae: 2.1081 - val_loss: 11.0451 - val_y1_output_loss: 1.9118 - val_y1_output_mae: 1.0140 - val_y2_output_loss: 9.3979 - val_y2_output_mae: 2.0511
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.1333 - y1_output_loss: 9.2045 - y1_output_mae: 2.1054 - y2_output_loss: 10.2602 - y2_output_mae: 2.2772 - val_loss: 13.8566 - val_y1_output_loss: 1.8278 - val_y1_output_mae: 0.9936 - val_y2_output_loss: 12.3581 - val_y2_output_mae: 2.4977
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.9947 - y1_output_loss: 8.1198 - y1_output_mae: 2.0598 - y2_output_loss: 8.5164 - y2_output_mae: 2.0251 - val_loss: 16.1564 - val_y1_output_loss: 3.5070 - val_y1_output_mae: 1.3781 - val_y2_output_loss: 13.0684 - val_y2_output_mae: 2.5272
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.3858 - y1_output_loss: 8.7213 - y1_output_mae: 2.0013 - y2_output_loss: 8.2671 - y2_output_mae: 1.9803 - val_loss: 15.8512 - val_y1_output_loss: 2.2187 - val_y1_output_mae: 1.0662 - val_y2_output_loss: 14.0126 - val_y2_output_mae: 2.6682
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.8246 - y1_output_loss: 7.7313 - y1_output_mae: 1.9224 - y2_output_loss: 7.2271 - y2_output_mae: 1.9668 - val_loss: 20.4413 - val_y1_output_loss: 3.3583 - val_y1_output_mae: 1.3238 - val_y2_output_loss: 17.5591 - val_y2_output_mae: 3.0531
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.3183 - y1_output_loss: 9.2709 - y1_output_mae: 2.0881 - y2_output_loss: 8.2671 - y2_output_mae: 2.0737 - val_loss: 19.9057 - val_y1_output_loss: 4.9739 - val_y1_output_mae: 1.6654 - val_y2_output_loss: 15.3574 - val_y2_output_mae: 2.8410
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.6006 - y1_output_loss: 8.5501 - y1_output_mae: 2.0662 - y2_output_loss: 9.1775 - y2_output_mae: 2.0798 - val_loss: 20.5747 - val_y1_output_loss: 4.3825 - val_y1_output_mae: 1.5751 - val_y2_output_loss: 16.6514 - val_y2_output_mae: 2.9911
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.4240 - y1_output_loss: 7.4025 - y1_output_mae: 2.0391 - y2_output_loss: 7.6445 - y2_output_mae: 2.0263 - val_loss: 18.0692 - val_y1_output_loss: 3.3854 - val_y1_output_mae: 1.3799 - val_y2_output_loss: 15.1118 - val_y2_output_mae: 2.7894
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.6777 - y1_output_loss: 8.0264 - y1_output_mae: 2.0023 - y2_output_loss: 7.8300 - y2_output_mae: 1.9939 - val_loss: 16.4909 - val_y1_output_loss: 3.4672 - val_y1_output_mae: 1.4505 - val_y2_output_loss: 13.4485 - val_y2_output_mae: 2.6143
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.1743 - y1_output_loss: 7.6068 - y1_output_mae: 2.0193 - y2_output_loss: 8.6925 - y2_output_mae: 2.0923 - val_loss: 22.2186 - val_y1_output_loss: 4.1306 - val_y1_output_mae: 1.5125 - val_y2_output_loss: 18.6099 - val_y2_output_mae: 3.1670
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.2229 - y1_output_loss: 7.1231 - y1_output_mae: 1.8989 - y2_output_loss: 7.9679 - y2_output_mae: 2.0671 - val_loss: 17.7459 - val_y1_output_loss: 2.4875 - val_y1_output_mae: 1.1910 - val_y2_output_loss: 15.7023 - val_y2_output_mae: 2.8863

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Evaluamos el modelo
results = model.evaluate(X_test, [y1_test, y2_test], verbose=0)

test_loss, y1_loss, y2_loss, test_mae_heating, test_mae_cooling = results

print(f"Total Test Loss: {test_loss:.4f}")
print(f"Heating Loss: {y1_loss:.4f}, Cooling Loss: {y2_loss:.4f}")
print(f"Test MAE for Heating Load: {test_mae_heating:.4f} Wh")
print(f"Test MAE for Cooling Load: {test_mae_cooling:.4f} Wh")
# Out:
# Total Test Loss: 17.7459
# Heating Loss: 2.4875, Cooling Loss: 15.7023
# Test MAE for Heating Load: 1.1910 Wh
# Test MAE for Cooling Load: 2.8863 Wh

# %%
import matplotlib.pyplot as plt


print(history.history.keys())

# ---- Graficamos el loss, que en este caso decidimos que fuera el MSE
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Total Training Loss')
plt.plot(history.history['val_loss'], label='Total Validation Loss')
plt.plot(history.history['y1_output_loss'], label='Heating Training Loss')
plt.plot(history.history['val_y1_output_loss'], label='Heating Validation Loss')
plt.plot(history.history['y2_output_loss'], label='Cooling Training Loss')
plt.plot(history.history['val_y2_output_loss'], label='Cooling Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# Graficamos el MAE
plt.figure(figsize=(10, 6))
plt.plot(history.history['y1_output_mae'], label='Heating Training MAE')
plt.plot(history.history['val_y1_output_mae'], label='Heating Validation MAE')
plt.plot(history.history['y2_output_mae'], label='Cooling Training MAE')
plt.plot(history.history['val_y2_output_mae'], label='Cooling Validation MAE')
plt.title('Model MAE over Epochs')
plt.xlabel('Epochs')
plt.ylabel('MAE (Wh)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Realizar predicciones
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

#Como tenemos dos targets, las predicciones hay que separarlas
y_train_pred_heating = y_pred_train[0].flatten()
y_train_pred_cooling = y_pred_train[1].flatten()

y_test_pred_heating = y_pred_test[0].flatten()
y_test_pred_cooling = y_pred_test[1].flatten()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
#Metricas de performance para heating

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score

def regression_metrics(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(root_mean_squared_error(y_true, y_pred))
    return r2, mae, rmse

# Metricas train
r2_train_heat, mae_train_heat, rmse_train_heat = regression_metrics(y1_train, y_train_pred_heating)
r2_train_cool, mae_train_cool, rmse_train_cool = regression_metrics(y2_train, y_train_pred_cooling)
print("=== Train Performance ===")
print(f"Heating Load: R²={r2_train_heat:.3f}, MAE={mae_train_heat:.3f}, RMSE={rmse_train_heat:.3f}")
print(f"Cooling Load: R²={r2_train_cool:.3f}, MAE={mae_train_cool:.3f}, RMSE={rmse_train_cool:.3f}")

# metricas test
r2_test_heat, mae_test_heat, rmse_test_heat = regression_metrics(y1_test, y_test_pred_heating)
r2_test_cool, mae_test_cool, rmse_test_cool = regression_metrics(y2_test, y_test_pred_cooling)
print("\n=== Test Performance ===")
print(f"Heating Load: R²={r2_test_heat:.3f}, MAE={mae_test_heat:.3f}, RMSE={rmse_test_heat:.3f}")
print(f"Cooling Load: R²={r2_test_cool:.3f}, MAE={mae_test_cool:.3f}, RMSE={rmse_test_cool:.3f}")
# Out:
# === Train Performance ===
# Heating Load: R²=0.979, MAE=1.112, RMSE=1.210
# Cooling Load: R²=0.853, MAE=2.607, RMSE=1.906
#
# === Test Performance ===
# Heating Load: R²=0.976, MAE=1.191, RMSE=1.252
# Cooling Load: R²=0.835, MAE=2.886, RMSE=1.977

# %% [markdown]
# #### Cross Validation

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models

def build_model(input_dim):
    input_layer = layers.Input(shape=(input_dim,))
    
    # Capas compartidas
    x = layers.Dense(128, activation='relu')(input_layer)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    
    # Heating
    h = layers.Dense(64, activation='relu')(x)
    h = layers.Dropout(0.2)(h)
    h = layers.Dense(32, activation='relu')(h)
    y1 = layers.Dense(1, name='heating_output')(h)
    
    # Cooling
    c = layers.Dense(64, activation='relu')(x)
    c = layers.Dropout(0.2)(c)
    c = layers.Dense(32, activation='relu')(c)
    y2 = layers.Dense(1, name='cooling_output')(c)
    
    model = models.Model(inputs=input_layer, outputs=[y1, y2])
    model.compile(optimizer='adam', loss='mse')
    return model

# %%
from sklearn.model_selection import KFold

from sklearn.preprocessing import StandardScaler
from numpy import sqrt

#KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

r2_heat, r2_cool = [], []
mae_heat, mae_cool = [], []
rmse_heat, rmse_cool = [], []

for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f"\n Fold {fold+1}")
    
    # Split data
    X_train, X_val = X[train_idx], X[val_idx]
    y_train_heat, y_val_heat = df['Y1'][train_idx], df['Y1'][val_idx]
    y_train_cool, y_val_cool = df['Y2'][train_idx], df['Y2'][val_idx]
    
    # Scale inputs
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    
    # Build & train model
    model = build_model(X.shape[1])
    model.fit(
        X_train, [y_train_heat, y_train_cool],
        epochs=80, batch_size=32, verbose=0
    )
    
    # Predict
    y_pred_heat, y_pred_cool = model.predict(X_val, verbose=0)
    
    # Flatten
    y_pred_heat, y_pred_cool = y_pred_heat.flatten(), y_pred_cool.flatten()
    
    # Compute metrics
    r2_heat.append(r2_score(y_val_heat, y_pred_heat))
    r2_cool.append(r2_score(y_val_cool, y_pred_cool))
    mae_heat.append(mean_absolute_error(y_val_heat, y_pred_heat))
    mae_cool.append(mean_absolute_error(y_val_cool, y_pred_cool))
    rmse_heat.append(sqrt(mean_squared_error(y_val_heat, y_pred_heat)))
    rmse_cool.append(sqrt(mean_squared_error(y_val_cool, y_pred_cool)))
# Out:
#  Fold 1
#
#  Fold 2
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000018E3B544720> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 3
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000018E3A4C0C20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 4
#
#  Fold 5

# %%
print("\n=== Cross-Validation Results ===")
print(f"Heating Load: R2={np.mean(r2_heat):.3f}±{np.std(r2_heat):.3f}, "
      f"MAE={np.mean(mae_heat):.3f}, RMSE={np.mean(rmse_heat):.3f}")
print(f"Cooling Load: R2={np.mean(r2_cool):.3f}±{np.std(r2_cool):.3f}, "
      f"MAE={np.mean(mae_cool):.3f}, RMSE={np.mean(rmse_cool):.3f}")
# Out:
# === Cross-Validation Results ===
# Heating Load: R2=0.952±0.025, MAE=1.668, RMSE=2.089
# Cooling Load: R2=0.929±0.021, MAE=1.839, RMSE=2.481

# %% [markdown]
# ## Tuneo de hiperparametros
#
# Especificamente diseniado para redes neuronales

# %%
# Random Serach
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models, optimizers

df = pd.read_csv("ENB2012_data.csv")
X_full = df[['X1','X2','X3','X4','X5','X6','X7','X8']].values
y1_full = df['Y1'].values
y2_full = df['Y2'].values

scaler = StandardScaler()
X_full = scaler.fit_transform(X_full)


X_train_full, X_test_full, y1_train_full, y1_test_full, y2_train_full, y2_test_full = train_test_split(
    X_full, y1_full, y2_full, test_size=0.2, random_state=42
)


# Definimos el contructor del modelo

def build_random_model(params, input_dim):
    input_layer = layers.Input(shape=(input_dim,))
    
    # compartidas
    x = input_layer
    for i in range(params['n_shared_layers']):
        x = layers.Dense(params['n_shared_units'], activation='relu')(x)
        x = layers.Dropout(params['dropout_rate'])(x)
    
    # Heating 
    h = layers.Dense(params['n_shared_units']//2, activation='relu')(x)
    y1 = layers.Dense(1, name='heating_output')(h)
    
    # Cooling 
    c = layers.Dense(params['n_shared_units']//2, activation='relu')(x)
    y2 = layers.Dense(1, name='cooling_output')(c)
    
    model = models.Model(inputs=input_layer, outputs=[y1, y2])
    
    opt = optimizers.Adam(learning_rate=params['learning_rate'])
    model.compile(
        optimizer=opt,
        loss={'heating_output': 'mse', 'cooling_output': 'mse'},
        metrics={'heating_output': 'mae', 'cooling_output': 'mae'}
    )
    
    return model


# Espacio para el random search

param_distributions = {
    'n_shared_layers': [1, 2, 3],
    'n_shared_units': [32, 64, 128, 256],
    'dropout_rate': [0.0, 0.1, 0.2, 0.3, 0.4],
    'learning_rate': [1e-4, 5e-4, 1e-3, 5e-3],
    'batch_size': [16, 32, 64]
}


n_trials = 5
results = []

print("\n Empezamos Random Search")
for i in range(n_trials):
    params = {k: random.choice(v) for k, v in param_distributions.items()}
    print(f"\nTrial {i+1}/{n_trials} with params: {params}")
    
    X_train_rs, X_val_rs, y1_train_rs, y1_val_rs, y2_train_rs, y2_val_rs = train_test_split(
        X_train_full, y1_train_full, y2_train_full, test_size=0.2, random_state=i
    )
    
    model = build_random_model(params, X_train_rs.shape[1])
    history = model.fit(
        X_train_rs, [y1_train_rs, y2_train_rs],
        validation_data=(X_val_rs, [y1_val_rs, y2_val_rs]),
        epochs=50, batch_size=params['batch_size'], verbose=0
    )
    
    val_loss = np.mean(history.history['val_loss'][-5:])
    results.append((params, val_loss))
    print(f"Validation Loss: {val_loss:.4f}")

# Resultados
results.sort(key=lambda x: x[1])
print("\n Results")
for rank, (params, loss) in enumerate(results, 1):
    print(f"{rank:2d}) Val Loss={loss:.4f} | Params={params}")

best_params, best_loss = results[0]
print("\n Mejor configuracion:")
print(best_params)
print(f"Validation Loss: {best_loss:.4f}")
# Out:
#  Empezamos Random Search
#
# Trial 1/5 with params: {'n_shared_layers': 3, 'n_shared_units': 64, 'dropout_rate': 0.0, 'learning_rate': 0.0001, 'batch_size': 32}
# Validation Loss: 45.3276
#
# Trial 2/5 with params: {'n_shared_layers': 3, 'n_shared_units': 64, 'dropout_rate': 0.2, 'learning_rate': 0.005, 'batch_size': 16}
# Validation Loss: 12.9404
#
# Trial 3/5 with params: {'n_shared_layers': 1, 'n_shared_units': 256, 'dropout_rate': 0.1, 'learning_rate': 0.0005, 'batch_size': 64}
# Validation Loss: 32.4682
#
# Trial 4/5 with params: {'n_shared_layers': 2, 'n_shared_units': 32, 'dropout_rate': 0.3, 'learning_rate': 0.005, 'batch_size': 32}
# Validation Loss: 14.6737
#
# Trial 5/5 with params: {'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.4, 'learning_rate': 0.0005, 'batch_size': 16}
# Validation Loss: 32.5929
#
#  Results
#  1) Val Loss=12.9404 | Params={'n_shared_layers': 3, 'n_shared_units': 64, 'dropout_rate': 0.2, 'learning_rate': 0.005, 'batch_size': 16}
#  2) Val Loss=14.6737 | Params={'n_shared_layers': 2, 'n_shared_units': 32, 'dropout_rate': 0.3, 'learning_rate': 0.005, 'batch_size': 32}
#  3) Val Loss=32.4682 | Params={'n_shared_layers': 1, 'n_shared_units': 256, 'dropout_rate': 0.1, 'learning_rate': 0.0005, 'batch_size': 64}
#  4) Val Loss=32.5929 | Params={'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.4, 'learning_rate': 0.0005, 'batch_size': 16}
#  5) Val Loss=45.3276 | Params={'n_shared_layers': 3, 'n_shared_units': 64, 'dropout_rate': 0.0, 'learning_rate': 0.0001, 'batch_size': 32}
#
#  Mejor configuracion:
# {'n_shared_layers': 3, 'n_shared_units': 64, 'dropout_rate': 0.2, 'learning_rate': 0.005, 'batch_size': 16}
# Validation Loss: 12.9404

# %% [markdown]
# #### Algunas referencias
#
# - https://keras.io/guides/sequential_model/
# - https://keras.io/api/layers/activations/
# - https://keras.io/optimizers/
# - https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-gauss&learningRate=0.03&regularizationRate=0.003&noise=20&networkShape=4&seed=0.82538&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=regression&initZero=false&hideText=false
